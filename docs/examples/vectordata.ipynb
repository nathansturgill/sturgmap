# %%
from ipyleaflet import basemaps

# %%
basemaps.OpenTopoMap
# Out:
# {'url': 'https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png',
#  'max_zoom': 17,
#  'html_attribution': 'Map data: &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, <a href="http://viewfinderpanoramas.org">SRTM</a> | Map style: &copy; <a href="https://opentopomap.org">OpenTopoMap</a> (<a href="https://creativecommons.org/licenses/by-sa/3.0/">CC-BY-SA</a>)',
#  'attribution': 'Map data: (C) OpenStreetMap contributors, SRTM | Map style: (C) OpenTopoMap (CC-BY-SA)',
#  'name': 'OpenTopoMap'}

# %%
import sturgmap

# %%
m = sturgmap.Map()
m.add_basemap('basemap1')

m
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 m = sturgmap.Map()
# ----> 2 m.add_basemap('basemap1')
#       4 m
#
# File ~/Downloads/sturgmap/sturgmap/sturgmap.py:35, in add_basemap(self, basemap)
#      33 if isinstance(name, str) and name in self.basemaps:
#      34     url = self.basemaps[name]
# ---> 35     self.add_tile_layer(url, name)
#      36 else:
#      37     print("Basemap not found or invalid input.")
#
# File ~/anaconda3/envs/geo/lib/python3.11/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File ~/anaconda3/envs/geo/lib/python3.11/site-packages/traitlets/traitlets.py:690, in TraitType.set(self, obj, value)
# ...
